# %%
import sys  
sys.path.insert(0, './gore')
import gore
import ipywidgets as widgets

# %%
rotary = gore.make_rotary(im_path = './img/fundus_white.jpg', 
                 focal_length = 24, 
                 alpha_max = gore.deg2rad(32), 
                 num_gores = 6, 
                 projection = "cassini", 
                 alpha_limit = gore.deg2rad(100), 
                 num_points = 1000,
                 phi_no_cut = gore.deg2rad(10))
# Out:
# Processing coordinate positions: 100%|██████████| 999/999 [00:36<00:00, 27.24it/s]
# Processing image rows: 100%|██████████| 1000/1000 [00:06<00:00, 153.53it/s]
# Processing image rows: 100%|██████████| 1000/1000 [00:12<00:00, 77.89it/s]
# Processing image rows: 100%|██████████| 1000/1000 [00:14<00:00, 67.60it/s]
# Processing image rows: 100%|██████████| 1000/1000 [00:04<00:00, 214.95it/s]

# %%
gore.fig(rotary)
rotary.save("rotary.png")
